# %%
import pandas as pd

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
with open('/content/drive/My Drive/ECE 539/ECE 539 Project/df.csv', 'r') as f: 
  df= pd.read_csv(f)

with open('/content/drive/My Drive/ECE 539/ECE 539 Project/GME_prices.csv', 'r') as f: 
  gme= pd.read_csv(f)

# %%
gme['Date'] = pd.to_datetime(gme['Date']).dt.date

# %%
df
# Out:
#        Unnamed: 0                                              title  score  \
# 0               0  ['$', 'cbat', '$', 'sunw', '$', 'spi', '$', 'o...      4
# 1               1  ['got', 'late', 'gme', 'believe', 'cause', 'wi...     75
# 2               2  ['highest', 'si', '%', 'float', 'end', 'busine...     26
# 3               3                               ['discord', 'still']      0
# 4               4                                       ['amc', '?']     67
# ...           ...                                                ...    ...
# 24718       24718              ['zeta', 'global', 'holdings…', 'dd']      0
# 24719       24719                           ['rkt', 'week', 'ahead']     58
# 24720       24720  ['verizon', '(', '$', 'vz', ')', '–', 'boomer'...     13
# 24721       24721            ['$', 'hipo', '-', 'hippo', 'holdings']     13
# 24722       24722            the clov clinician letter is worth read     59
#
# ...

# %%
gme
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2021-01-04   19.000000   19.100000   17.150000   17.250000   17.250000
# 1    2021-01-05   17.350000   18.080000   17.230000   17.370001   17.370001
# 2    2021-01-06   17.340000   18.980000   17.330000   18.360001   18.360001
# 3    2021-01-07   18.469999   19.450001   18.020000   18.080000   18.080000
# 4    2021-01-08   18.180000   18.299999   17.080000   17.690001   17.690001
# ..          ...         ...         ...         ...         ...         ...
# 329  2022-04-25  135.410004  139.710007  133.279999  135.949997  135.949997
# 330  2022-04-26  135.639999  136.800003  126.160004  127.599998  127.599998
# 331  2022-04-27  127.269997  132.679993  124.580002  129.839996  129.839996
# 332  2022-04-28  130.279999  132.600006  120.500000  129.309998  129.309998
# 333  2022-04-29  127.300003  130.889999  123.010002  124.010002  124.010002
#
#        Volume
# 0    10022500
# 1     4961500
# ...

# %%
# for i in range(len(df)):
#   print(gme.index[gme['Date']==df.Date[i]].tolist())
#   # df[["Open"]][i] = gme[["Open"]][(gme.Date == df.Date[i])]
mega = df.merge(right=gme, left_on='Date', left=df, right_on='Date')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-39572b74612e> in <module>()
#       2 #   print(gme.index[gme['Date']==df.Date[i]].tolist())
#       3 #   # df[["Open"]][i] = gme[["Open"]][(gme.Date == df.Date[i])]
# ----> 4 mega = df.merge(right=gme, left_on='Date', left=df, right_on='Date')
#
# NameError: name 'df' is not defined

# %%
mega
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, title, score, comms_num, body, timestamp, Unnamed: 8, Unnamed: 9, Unnamed: 10, Unnamed: 11, gme, amc, title_sentiment, body_sentiment, Date, Time, Open, High, Low, Close, Adj Close, Volume]
# Index: []
#
# [0 rows x 22 columns]
